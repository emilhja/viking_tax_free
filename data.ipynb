# %%
import os
import pandas as pd

def load_and_combine_csvs(folder_path):
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    dataframe_list = []

    for csv_file in csv_files:
        file_path = os.path.join(folder_path, csv_file)
        df = pd.read_csv(file_path)
        dataframe_list.append(df)

    # Concatenate all DataFrames, ignoring index to avoid index conflicts
    combined_df = pd.concat(dataframe_list, axis=0, ignore_index=True, sort=False)
    
    return combined_df

folder = 'raw_data'
combined_dataframe = load_and_combine_csvs(folder)

df = combined_dataframe.copy()
df
# Out:
#          id                                       name  \
# 0    108779         Bottega Amarone della Valpolicella
# 1    108556         Bottega Cabernet delle Venezie IGT
# 2    108843          Bottega Chianti Classico D.O.C.G.
# 3    118584                Bottega Collio Pinot Grigio
# 4    118035  Bottega Pinot Grigio delle Venezie I.G.T.
# ..      ...                                        ...
# 422  108529         Tommasi Graticcio Appassionato BIB
# 423  109700                 Tommasi La Prunee - Merlot
# 424  118540            Tommasi Le Fornaci - Lugana DOC
# 425  118534          Tommasi Le Volpare Soave Classico
# 426  119803          Tommasi Masseria Surani Fiano IGT
#
#                                            description  price_sek  price_eur  \
# 0    Amarone is a full bodied, balanced and pleasan...      29.95        NaN
# 1    Cabernet Sauvignon Igt delle Venezie is a powe...       7.50        NaN
# 2                                                  NaN      14.50        NaN
# 3                                                  NaN      12.50        NaN
# 4    Pinot Grigio Igt delle Venezie is a dry wine w...       8.50        NaN
# ..                                                 ...        ...        ...
# 422  Kryddig smak med inslag av fat, körsbär, kanel...      20.95        NaN
# 423    Medelfyllig, medelhöga tanniner, kryddig, bärig      10.95        NaN
# 424  Torr, medelhög syra, grapefruktskaraktär, fruktig      12.95        NaN
# 425  En blek halmgul färg med lysande gröna toner. ...       9.95        NaN
# 426  Halmgult, aromrik och frisk doft. Vinet har de...      14.95        NaN
#
#      category                brand  country  volume  alcohol_percentage  ...  \
# 0         NaN             Bottega       NaN     NaN                 NaN  ...
# 1         NaN             Bottega       NaN     NaN                 NaN  ...
# 2         NaN             Bottega       NaN     NaN                 NaN  ...
# 3         NaN             Bottega       NaN     NaN                 NaN  ...
# 4         NaN             Bottega       NaN     NaN                 NaN  ...
# ..        ...                  ...      ...     ...                 ...  ...
# 422       NaN  Tommasi Viticoltori      NaN     NaN                 NaN  ...
# 423       NaN  Tommasi Viticoltori      NaN     NaN                 NaN  ...
# 424       NaN  Tommasi Viticoltori      NaN     NaN                 NaN  ...
# 425       NaN  Tommasi Viticoltori      NaN     NaN                 NaN  ...
# 426       NaN  Tommasi Viticoltori      NaN     NaN                 NaN  ...
#
#     producer  year  volume_detail alcohol_detail detailed_description  \
# 0        NaN   NaN            NaN            NaN                  NaN
# 1        NaN   NaN            NaN            NaN                  NaN
# 2        NaN   NaN            NaN            NaN                  NaN
# 3        NaN   NaN            NaN            NaN                  NaN
# 4        NaN   NaN            NaN            NaN                  NaN
# ..       ...   ...            ...            ...                  ...
# 422      NaN   NaN            NaN            NaN                  NaN
# 423      NaN   NaN            NaN            NaN                  NaN
# 424      NaN   NaN            NaN            NaN                  NaN
# 425      NaN   NaN            NaN            NaN                  NaN
# 426      NaN   NaN            NaN            NaN                  NaN
#
#     detailed_price image_urls  food_pairing.1  character.1  grape_variety.1
# 0              NaN        NaN             NaN          NaN              NaN
# 1              NaN        NaN             NaN          NaN              NaN
# 2              NaN        NaN             NaN          NaN              NaN
# 3              NaN        NaN             NaN          NaN              NaN
# 4              NaN        NaN             NaN          NaN              NaN
# ..             ...        ...             ...          ...              ...
# 422            NaN        NaN             NaN          NaN              NaN
# 423            NaN        NaN             NaN          NaN              NaN
# 424            NaN        NaN             NaN          NaN              NaN
# 425            NaN        NaN             NaN          NaN              NaN
# 426            NaN        NaN             NaN          NaN              NaN
#
# [427 rows x 29 columns]

# %%
df.info()

# show nan columns
nan_columns = df.columns[df.isna().any()].tolist()
print("Columns with NaN values:")
nan_columns

df = df.dropna(axis=1, how='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427 entries, 0 to 426
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    427 non-null    int64
#  1   name                  427 non-null    object
#  2   description           345 non-null    object
#  3   price_sek             427 non-null    float64
#  4   price_eur             0 non-null      float64
#  5   category              0 non-null      float64
#  6   brand                 427 non-null    object
#  7   country               0 non-null      float64
#  8   volume                0 non-null      float64
#  9   alcohol_percentage    0 non-null      float64
#  10  image_url             427 non-null    object
#  11  in_stock              0 non-null      float64
#  12  article_number        0 non-null      float64
#  13  detailed_title        20 non-null     object
#  14  food_pairing          314 non-null    object
#  15  character             313 non-null    object
#  16  grape_variety         270 non-null    object
#  17  country_detail        0 non-null      float64
#  18  region                0 non-null      float64
#  19  producer              0 non-null      float64
#  20  year                  0 non-null      float64
#  21  volume_detail         0 non-null      float64
#  22  alcohol_detail        0 non-null      float64
#  23  detailed_description  0 non-null      float64
#  24  detailed_price        0 non-null      float64
#  25  image_urls            0 non-null      float64
#  26  food_pairing.1        50 non-null     object
#  27  character.1           49 non-null     object
#  28  grape_variety.1       43 non-null     object
# dtypes: float64(17), int64(1), object(11)
# memory usage: 96.9+ KB
# Columns with NaN values:

# %%
df = df.set_index('id')
df = df.rename(columns={'price_sek': 'price_eur'})
df.sample(15)
# Out:
#                                           name  \
# id
# 107831                          Norton Privada
# 109498                Black Cottage Pinot Noir
# 110183                 Trivento Reserve Malbec
# 110176                            Ocho dos dos
# 109888                       Ramos Reserva BIB
# 117011                   Torres Viña Esmeralda
# 119216                Leitz 4 Friends Riesling
# 119599                 Riley's Rows Chardonnay
# 127280               Zinzula Masseria Altemura
# 110054        Baron de Ley Gran Reserva Magnum
# 109463             Renato Ratti Barbera d'Asti
# 107930               Torres Sangre de Toro BIB
# 119714         Cape Original Fruity & Tropical
# 108750           JP. Chenet Cabernet-Syrah BIB
# 119923  Muré Gewurztraminer Orchidées Sauvages
#
#                                               description  price_eur  \
# id
# 107831  Fyllig, höga tanniner, toner av mörka körsbär,...      13.50
# 109498  Intensiv doft av körsbär, jordgubbe och hallon...      16.50
# 110183  Djupt röd med violetta nyanser. Intensiva arom...       7.95
# 110176  Ett Riberavin med karaktär. Ljus röd färg med ...      19.95
# 109888  Dark, blue-red color. Fruity taste with hints ...      19.95
# 117011  Torr, medelhög syra, citruskaraktär, persikaka...       8.50
# 119216  NOSE: Fruity nose with peach, apricot and appl...      10.50
# 119599                                                NaN      39.95
# 127280  En fantastisk torr, fruktig och frisk rosé på ...      11.50
# 110054  Vinet är behagligt rubinrött, vid glaskanten n...      49.95
# 109463  Intensiv, rubinröd. Mogen bukett med en underl...      19.95
# 107930  Medelfyllig, höga tanniner, toner av körsbärss...      23.95
# 119714  Halvtorr, låg syra, klementinkaraktär, päronka...       7.95
# 108750  The grapes are harvested when ripe, destemmed,...      17.95
# 119923                                                NaN      18.50
#
#                              brand                     image_url  \
# id
# 107831                      Norton  /owif/images/107831?size=300
# 109498        Black Cottage Wines   /owif/images/109498?size=300
# 110183                    Trivento  /owif/images/110183?size=300
# 110176                Juvé & Camps  /owif/images/110176?size=300
# 109888    J. Portugal Ramos Vinhos  /owif/images/109888?size=300
# 117011  Miguel Torres Spain Winery  /owif/images/117011?size=300
# 119216                       Leitz  /owif/images/119216?size=300
# 119599                Riley's Rows  /owif/images/119599?size=300
# 127280          Masseria Altemura   /owif/images/127280?size=300
# 110054                Baron de Ley  /owif/images/110054?size=300
# 109463                Renato Ratti  /owif/images/109463?size=300
# 107930  Miguel Torres Spain Winery  /owif/images/107930?size=300
# 119714                 Origin Wine  /owif/images/119714?size=300
# 108750                  JP. Chenet  /owif/images/108750?size=300
# 119923                        Muré  /owif/images/119923?size=300
#
#                  detailed_title  \
# id
# 107831                      NaN
# 109498                      NaN
# 110183                      NaN
# 110176                      NaN
# 109888                      NaN
# 117011                      NaN
# 119216                      NaN
# 119599                      NaN
# 127280                      NaN
# 110054  Pardon Our Interruption
# 109463                      NaN
# 107930                      NaN
# 119714                      NaN
# 108750                      NaN
# 119923                      NaN
#
#                                              food_pairing     character  \
# id
# 107831                                   Nöt Grillat Gris       Fylligt
# 109498                                                NaN           NaN
# 110183                                  Grillat Biff Gris       Fylligt
# 110176                                      Nöt Lamm Vilt       Fylligt
# 109888                                 Lamm Pasta Grillat       Fylligt
# 117011             Asiatiskt Buffé Aperitif, sällskapsvin     Halvtorrt
# 119216  Sallader, vegetariskt Fiskrätter Aperitif, säl...         Torrt
# 119599                   Kyckling, kalkon Fiskrätter Gris         Torrt
# 127280         Skaldjur Fiskrätter Aperitif, sällskapsvin         Torrt
# 110054                                                NaN           NaN
# 109463                                    Pasta Gris Kalv  Medelfylligt
# 107930                                   Nöt Vilt Grillat  Medelfylligt
# 119714                                                NaN           NaN
# 108750                                      Nöt Lamm Gris  Medelfylligt
# 119923                Skaldjur Kyckling, kalkon Asiatiskt     Halvtorrt
#
#                            grape_variety  \
# id
# 107831  Cabernet Sauvignon Merlot Malbec
# 109498                               NaN
# 110183                            Malbec
# 110176                       Tempranillo
# 109888        Syrah Aragones Trincadeira
# 117011          Gewurtstraminer Moscatel
# 119216                          Riesling
# 119599                               NaN
# 127280                        Negroamaro
# 110054                               NaN
# 109463                               NaN
# 107930                         Parellada
# 119714                               NaN
# 108750                               NaN
# 119923                   Gewurtstraminer
#
#                               food_pairing.1   character.1 grape_variety.1
# id
# 107831                                   NaN           NaN             NaN
# 109498  Skaldjur Kyckling, kalkon Vilt Ostar  Medelfylligt      Pinot Noir
# 110183                                   NaN           NaN             NaN
# 110176                                   NaN           NaN             NaN
# 109888                                   NaN           NaN             NaN
# 117011                                   NaN           NaN             NaN
# 119216                                   NaN           NaN             NaN
# 119599                                   NaN           NaN             NaN
# 127280                                   NaN           NaN             NaN
# 110054                      Nöt Lamm Grillat       Fylligt     Tempranillo
# 109463                                   NaN           NaN             NaN
# 107930                                   NaN           NaN             NaN
# 119714                                   NaN           NaN             NaN
# 108750                                   NaN           NaN             NaN
# 119923                                   NaN           NaN             NaN

# %%
nan_rows = df[df.isna().any(axis=1)]
nan_rows
# Out:
#                                              name  \
# id
# 108779         Bottega Amarone della Valpolicella
# 108556         Bottega Cabernet delle Venezie IGT
# 108843          Bottega Chianti Classico D.O.C.G.
# 118584                Bottega Collio Pinot Grigio
# 118035  Bottega Pinot Grigio delle Venezie I.G.T.
# ...                                           ...
# 108529         Tommasi Graticcio Appassionato BIB
# 109700                 Tommasi La Prunee - Merlot
# 118540            Tommasi Le Fornaci - Lugana DOC
# 118534          Tommasi Le Volpare Soave Classico
# 119803          Tommasi Masseria Surani Fiano IGT
#
#                                               description  price_eur  \
# id
# 108779  Amarone is a full bodied, balanced and pleasan...      29.95
# 108556  Cabernet Sauvignon Igt delle Venezie is a powe...       7.50
# 108843                                                NaN      14.50
# 118584                                                NaN      12.50
# 118035  Pinot Grigio Igt delle Venezie is a dry wine w...       8.50
# ...                                                   ...        ...
# 108529  Kryddig smak med inslag av fat, körsbär, kanel...      20.95
# 109700    Medelfyllig, medelhöga tanniner, kryddig, bärig      10.95
# 118540  Torr, medelhög syra, grapefruktskaraktär, fruktig      12.95
# 118534  En blek halmgul färg med lysande gröna toner. ...       9.95
# 119803  Halmgult, aromrik och frisk doft. Vinet har de...      14.95
#
#                       brand                     image_url detailed_title  \
# id
# 108779             Bottega   /owif/images/108779?size=300            NaN
# 108556             Bottega   /owif/images/108556?size=300            NaN
# 108843             Bottega   /owif/images/108843?size=300            NaN
# 118584             Bottega   /owif/images/118584?size=300            NaN
# 118035             Bottega   /owif/images/118035?size=300            NaN
# ...                     ...                           ...            ...
# 108529  Tommasi Viticoltori  /owif/images/108529?size=300            NaN
# 109700  Tommasi Viticoltori  /owif/images/109700?size=300            NaN
# 118540  Tommasi Viticoltori  /owif/images/118540?size=300            NaN
# 118534  Tommasi Viticoltori  /owif/images/118534?size=300            NaN
# 119803  Tommasi Viticoltori  /owif/images/119803?size=300            NaN
#
#                                      food_pairing     character grape_variety  \
# id
# 108779                                        NaN           NaN           NaN
# 108556                                        NaN           NaN           NaN
# 108843                                        NaN           NaN           NaN
# 118584                                        NaN           NaN           NaN
# 118035                                        NaN           NaN           NaN
# ...                                           ...           ...           ...
# 108529                           Nöt Lamm Grillat       Fylligt           NaN
# 109700            Nöt Kyckling, kalkon Gris Buffé  Medelfylligt        Merlot
# 118540  Sallader, vegetariskt Skaldjur Fiskrätter         Torrt      Turbiana
# 118534                  Skaldjur Fiskrätter Sushi         Torrt     Garganega
# 119803  Sallader, vegetariskt Skaldjur Fiskrätter         Torrt         Fiano
#
#        food_pairing.1 character.1 grape_variety.1
# id
# 108779            NaN         NaN             NaN
# 108556            NaN         NaN             NaN
# 108843            NaN         NaN             NaN
# 118584            NaN         NaN             NaN
# 118035            NaN         NaN             NaN
# ...               ...         ...             ...
# 108529            NaN         NaN             NaN
# 109700            NaN         NaN             NaN
# 118540            NaN         NaN             NaN
# 118534            NaN         NaN             NaN
# 119803            NaN         NaN             NaN
#
# [427 rows x 12 columns]
